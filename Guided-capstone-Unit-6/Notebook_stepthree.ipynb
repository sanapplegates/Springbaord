# %%
pwd
# Out:
# 'C:\\Users\\SANJAY\\Springboard\\Guided-capstone-Unit-6'

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SANJAY\\Springboard\\Guided-capstone-Unit-6'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data',
#  'figures',
#  'models',
#  'Notebook_stepthree.ipynb',
#  'Notebook_StepTwo.ipynb',
#  'ski_data_dict.png']

# %%
df=pd.read_csv("C:\\Users\\SANJAY\\Springboard\\Guided-capstone-Unit-6\data\step2_output.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0                 Name   Region    state  summit_elev  \
# 0           0       Alyeska Resort   Alaska   Alaska         3939
# 1           1  Eaglecrest Ski Area   Alaska   Alaska         2600
# 2           2     Hilltop Ski Area   Alaska   Alaska         2090
# 3           3     Arizona Snowbowl  Arizona  Arizona        11500
# 4           4  Sunrise Park Resort  Arizona  Arizona        11100
#
#    vertical_drop  base_elev  trams  fastEight  fastSixes  ...  Snow Making_ac  \
# 0           2500        250      1        0.0          0  ...           113.0
# 1           1540       1200      0        0.0          0  ...            60.0
# 2            294       1796      0        0.0          0  ...            30.0
# 3           2300       9200      0        0.0          1  ...           104.0
# 4           1800       9200      0        0.0          0  ...            80.0
#
#    daysOpenLastYear  yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# 0             150.0       60.0            669.0          65.0          85.0
# 1              45.0       44.0            350.0          47.0          53.0
# 2             150.0       36.0             69.0          30.0          34.0
# 3             122.0       81.0            260.0          89.0          89.0
# 4             115.0       49.0            250.0          74.0          78.0
#
#    projectedDaysOpen  NightSkiing_ac  total_chairlifts  differrence
# 0              150.0           550.0               4.0          3.0
# 1               90.0             0.0               4.0          0.0
# 2              152.0            30.0               3.0          0.0
# 3              122.0             0.0               7.0          1.0
# 4              104.0            80.0               6.0          1.0
#
# [5 rows x 30 columns]

# %%
df=df.drop(columns='differrence')
df.describe().T
# Out:
#                    count         mean          std    min      25%  \
# Unnamed: 0         330.0   164.500000    95.407023    0.0    82.25
# summit_elev        330.0  4591.818182  3735.535934  315.0  1403.75
# vertical_drop      330.0  1215.427273   947.864557   60.0   461.25
# base_elev          330.0  3374.000000  3117.121621   70.0   869.00
# trams              330.0     0.172727     0.559946    0.0     0.00
# fastEight          330.0     0.003030     0.055048    0.0     0.00
# fastSixes          330.0     0.184848     0.651685    0.0     0.00
# fastQuads          330.0     1.018182     2.198294    0.0     0.00
# quad               330.0     0.933333     1.312245    0.0     0.00
# triple             330.0     1.500000     1.619130    0.0     0.00
# double             330.0     1.833333     1.815028    0.0     1.00
# surface            330.0     2.621212     2.059636    0.0     1.00
# total_chairs       330.0     8.266667     5.798683    0.0     5.00
# Runs               330.0    48.214724    46.081366    3.0    19.00
# TerrainParks       330.0     2.384848     2.109556    0.0     1.00
# LongestRun_mi      330.0     1.433231     1.147352    0.0     0.60
# SkiableTerrain_ac  330.0   739.801223  1807.868079    8.0    85.00
# Snow Making_ac     330.0   150.496970   249.854380    0.0    30.00
# daysOpenLastYear   330.0   115.103943    32.231212    3.0   100.00
# yearsOpen          330.0    63.656535   109.263494    6.0    50.00
# averageSnowfall    330.0   185.316456   133.424094   18.0    71.25
# AdultWeekday       330.0    57.916957    23.898798   15.0    43.00
# AdultWeekend       330.0    64.166810    22.571324   17.0    49.00
# projectedDaysOpen  330.0   120.053004    28.742976   30.0   101.25
# NightSkiing_ac     330.0    56.890909    93.464882    0.0     0.00
# total_chairlifts   330.0     6.887879     3.775159    0.0     4.00
#
#                            50%          75%      max
# Unnamed: 0          164.500000   246.750000    329.0
# summit_elev        3127.500000  7806.000000  13487.0
# vertical_drop       964.500000  1800.000000   4425.0
# base_elev          1561.500000  6325.250000  10800.0
# trams                 0.000000     0.000000      4.0
# fastEight             0.000000     0.000000      1.0
# fastSixes             0.000000     0.000000      6.0
# fastQuads             0.000000     1.000000     15.0
# quad                  0.000000     1.000000      8.0
# triple                1.000000     2.000000      8.0
# double                1.000000     3.000000     14.0
# surface               2.000000     3.000000     15.0
# total_chairs          7.000000    10.000000     41.0
# Runs                 34.000000    60.000000    341.0
# TerrainParks          2.000000     3.000000     14.0
# LongestRun_mi         1.000000     2.000000      6.0
# SkiableTerrain_ac   200.000000   739.801223  26819.0
# Snow Making_ac       86.000000   192.000000   3379.0
# daysOpenLastYear    115.103943   130.000000    305.0
# yearsOpen            58.000000    68.750000   2019.0
# averageSnowfall     158.000000   278.750000    669.0
# AdultWeekday         57.916957    67.000000    179.0
# AdultWeekend         64.166810    72.000000    179.0
# projectedDaysOpen   120.053004   136.000000    305.0
# NightSkiing_ac       27.000000    83.750000    650.0
# total_chairlifts      6.000000     9.000000     27.0

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Name                  object
# Region                object
# state                 object
# summit_elev            int64
# vertical_drop          int64
# base_elev              int64
# trams                  int64
# fastEight            float64
# fastSixes              int64
# fastQuads              int64
# quad                   int64
# triple                 int64
# double                 int64
# surface                int64
# total_chairs           int64
# Runs                 float64
# TerrainParks         float64
# LongestRun_mi        float64
# SkiableTerrain_ac    float64
# Snow Making_ac       float64
# daysOpenLastYear     float64
# yearsOpen            float64
# averageSnowfall      float64
# AdultWeekday         float64
# AdultWeekend         float64
# projectedDaysOpen    float64
# NightSkiing_ac       float64
# total_chairlifts     float64
# dtype: object

# %%
hist=df.hist(bins=25,figsize=(25,25))

# %% [markdown]
# <b>State Levels plot</b>

# %%
#a barplot for the categorical features Region and state where the heights of the bars 
#are the counts of each level in that variable.
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(df.state.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.state into the list() function
values = list(x.state)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# <b>Region Levels plot</b>

# %%
f, ax = plt.subplots(figsize=(10, 10))

#  the value_counts() of the regions(Region) 
x = pd.DataFrame(df.Region.value_counts())

# Get the regions names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.Region into the list() function
values = list(x.Region)

# Now call the barplot() method on our sns seaborn object. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %%
print(df.state.value_counts())
print("\n",df.Region.value_counts())
# Out:
# New York          33
# Michigan          29
# Colorado          22
# California        21
# Pennsylvania      19
# Wisconsin         16
# New Hampshire     16
# Vermont           15
# Minnesota         14
# Utah              13
# Montana           12
# Idaho             12
# Massachusetts     11
# Washington        10
# Oregon            10
# New Mexico         9
# Maine              9
# Wyoming            8
# North Carolina     6
# Ohio               5
# Connecticut        5
# West Virginia      4
# Nevada             4
# Illinois           4
# Virginia           4
# Iowa               3
# Alaska             3
# South Dakota       2
# Missouri           2
# New Jersey         2
# Arizona            2
# Indiana            2
# Maryland           1
# Tennessee          1
# Rhode Island       1
# Name: state, dtype: int64
#
#  New York               33
# Michigan               29
# Sierra Nevada          22
# Colorado               22
# Pennsylvania           19
# New Hampshire          16
# Wisconsin              16
# Vermont                15
# Minnesota              14
# Idaho                  12
# Montana                12
# Massachusetts          11
# Washington             10
# New Mexico              9
# Maine                   9
# Wyoming                 8
# Utah                    7
# Salt Lake City          6
# Oregon                  6
# North Carolina          6
# Ohio                    5
# Connecticut             5
# West Virginia           4
# Illinois                4
# Mt. Hood                4
# Virginia                4
# Iowa                    3
# Alaska                  3
# South Dakota            2
# Missouri                2
# New Jersey              2
# Nevada                  2
# Arizona                 2
# Indiana                 2
# Tennessee               1
# Maryland                1
# Northern California     1
# Rhode Island            1
# Name: Region, dtype: int64

# %%
# the Region feature is nearly identical to the state and therfore we can remove from the dataframe. 
#Remove the Region column using the drop function.
df=df.drop(['Region'],axis=1) #use columns=['Region']
 

df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'state', 'summit_elev', 'vertical_drop',
#        'base_elev', 'trams', 'fastEight', 'fastSixes', 'fastQuads', 'quad',
#        'triple', 'double', 'surface', 'total_chairs', 'Runs', 'TerrainParks',
#        'LongestRun_mi', 'SkiableTerrain_ac', 'Snow Making_ac',
#        'daysOpenLastYear', 'yearsOpen', 'averageSnowfall', 'AdultWeekday',
#        'AdultWeekend', 'projectedDaysOpen', 'NightSkiing_ac',
#        'total_chairlifts'],
#       dtype='object')

# %% [markdown]
# ### Anamolies & Outliers - Review boxplots

# %% [markdown]
# <b>Print boxplot for every column</b>

# %%
boxplot = df.boxplot(grid=False, vert=False,fontsize=10,figsize=(12,15))

# %% [markdown]
# <b>Outliers</b> are extreme values that fall far outside the mean and standard deviation of a set of observations. They can mislead the training process in building machine learning models. Outliers may be real anomalies in the observations or artificial errors.
#
# One method for outlier analysis is extreme value analysis using a boxplot, which assumes a normal distribution. The figure below describes the components of a boxplot. Notice the outlier is the point outside the upper whisker end.
#
#
# <b>Follow these steps:</b>
#
# Create boxplots - earlier step
#
# Apply outlier removal using the Interquartile range or replacement
#
# Review how many observations were removed

# %%
# Let's get the Interquartile range, or IQR. This is equal to Q3 - Q1. 
# First, let's use the quantile() method to get the first quartile, and store it in a variable called Q1.
# We'll want to plug 0.25 into the quantile method. 
Q1 = df.quantile(0.25)

# Now get Q3 and store in a variable called Q3. 
Q3 = df.quantile(0.75)

# Now calculate the IQR, storing it in a variable called IQR.
IQR=Q3-Q1

# Make a variable called `dfno`, and assign it the value: df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]. 
# This filters on our existing dataframe, picking out just those observations that are NOT outliers. 
dfno=df[~((df< (Q1-1.5*IQR)) | (df> (Q1+1.5 * IQR))).any(axis=1)]

# We now want to make a boxplot of this new dataframe dfno. 
boxplot= dfno.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))

# %%
print(df.shape)
print(dfno.shape)
# Out:
# (330, 28)
# (73, 28)

# %% [markdown]
# <b>outlier removal in more depth in units 7 (Data Wrangling) and 10 (Statistics for Exploratory Data Analysis) of the course.</b>

# %% [markdown]
# for the rest of this guided capstone project, we will focus on increasing revenue by increasing the lift ticket prices and the number of days the resort is open per year.
#
# In this case, we need to investigate the expected lift ticket price for Big Mountain based on all the other given resort characteristics.
#
# In addition, we want to predict the number of days the resort will be open each season.

# %%
dfno['AdultWeekday'].hist()

# %%
dfno['AdultWeekend'].hist()

# %%
dfno['daysOpenLastYear'].hist()

# %%
dfno['projectedDaysOpen'].hist()

# %% [markdown]
#  # Explore data relationships

# %% [markdown]
# <b> pairplots ot biplots:</b>
# evaluate the variable distributions against each other is with the seaborn pair plots function.

# %%
#g=sns.pairplot(dfno) #pairplot

# %% [markdown]
# # Identification and creation of features

# %% [markdown]
# <b>Create a Pearson correlation heatmap</b>

# %%
#Calculate the correlation coefficients
corr =dfno.corr()
#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm') # Replacing Nan By 0
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col1 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col2 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col3 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col7 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col8 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col9 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col10 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col11 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col12 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col13 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col15 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col16 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col18 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col19 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col20 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col21 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col22 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col23 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col24 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row0_col25 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col0 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col2 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col3 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col7 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col8 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col9 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col10 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col12 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col13 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col14 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col15 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col16 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col17 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col18 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col19 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col20 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col21 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col22 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col23 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col24 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row1_col25 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row2_col0 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row2_col1 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row2_col3 {
#             background-color:  #f4987a;
#             color:  #000000;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_834ccfa4_aa4d_11ea_8538_a0d3c162c0a3row2_col7 {
#             background-color:  #6384eb;

# %% [markdown]
# When reviewing the Pearson correlation coefficient heatmap, you can see substantial differences in the correlations compared to the response variable(s) as well as in the features when compared to each other. The heatmap helps identify features that suffer from multi-collinearity.

# %% [markdown]
#  The correlation matrix displayed in the heatmap to select and remove collinear features. Remember to exclude the response variable(s) from the matrix to ensure they are retained in your final model development dataset. Then select those features that are more than 95% correlated for removal.
#
# Step 1: Create a correlation matrix that excludes your response variables.
#
# Step 2: Select the upper triangle of the correlation matrix. This is because a correlation matrix actually contains the same information, twice over!
#
# Step 3: Find the index of feature columns with a correlation greater than 0.95.

# %%
# Step 1. Call the variable corr_matrix
corr_matrix= dfno.drop(columns=['AdultWeekday','AdultWeekend','daysOpenLastYear','projectedDaysOpen'], axis=1).corr().abs()

# Step 2. Uncomment the following code to get the upper triangle of the correlation matrix 
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Step 3. This code iterates through our columns and gets the index of any that have a correlation > 0.95
# Call the variable to_drop, get the columns of our 'upper' variable, make sure the threshold is 0.95.
to_drop= [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
# Let's see those features! 
print('Features selected to drop include:',to_drop)
# Out:
# Features selected to drop include: ['base_elev', 'total_chairlifts']

# %%
print('Reduced dataframe size: ',dfno.drop(dfno[to_drop], axis=1).shape)
# Out:
# Reduced dataframe size:  (73, 26)

# %%
# Now replace dfno by the result of dropping the columns in the to_drop variable from it
dfno=dfno.drop(dfno[to_drop], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-792fb95108a2> in <module>
#       1 # Now replace dfno by the result of dropping the columns in the to_drop variable from it
# ----> 2 dfno=dfno.drop(dfno[to_drop], axis=1)
#       3 dfno.shape
#
# NameError: name 'dfno' is not defined

# %% [markdown]
#  The K-means algorithm is one way of doing clustering. It puts our data into groups (or 'clusters') which can then become features for further analysis. What the k-means algorithm outputs, though, depends on the number of clusters we set out to have. We will use a method called 'Elbow plotting' to determine this number

# %% [markdown]
# <b>The Elbow plot is a diagnostic tool that helps us determine the number of clusters to include in our k-means clustering implementation.</b>
#
# In this example, the error between clusters and within clusters is compared for a range of 1 to 11 clusters, and it appears the elbow is between two and four, therefore we set the parameter k = 3.

# %%
from sklearn.cluster import KMeans
x = dfno.drop(['Name','state'], axis = 1).values
x
# Out:
# array([[  15.        , 6890.        , 1435.        , ...,   59.        ,
#          130.        ,    0.        ],
#        [  43.        , 9895.        , 2010.        , ...,   65.        ,
#          135.        ,    0.        ],
#        [  49.        ,  525.        ,  425.        , ...,   60.        ,
#           95.        ,   51.        ],
#        ...,
#        [ 315.        , 1110.        ,  516.        , ...,   56.        ,
#          100.        ,   90.        ],
#        [ 323.        , 8000.        ,  640.        , ...,   48.        ,
#           95.        ,    0.        ],
#        [ 328.        , 9663.        ,  990.        , ...,   49.        ,
#          120.05300353,    0.        ]])

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(x)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %%
# This code will fit the k-means algorithm with our k parameter set to three, and plot the results. Cool, huh? 
kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')

centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
# Make a new column in your dfno dataframe called 'clusters', and assign it the variable: y_kmeans
dfno['clusters'] = y_kmeans3

# %%
print(os.getcwd())
print(os.listdir())
dfno.to_csv('data/step3_output.csv')
# Out:
# C:\Users\SANJAY\Springboard\Guided-capstone-Unit-6
# ['.ipynb_checkpoints', 'data', 'figures', 'models', 'Notebook_stepthree.ipynb', 'Notebook_StepTwo.ipynb', 'ski_data_dict.png']
